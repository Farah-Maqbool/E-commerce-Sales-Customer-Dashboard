# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("../data/Pakistan Largest Ecommerce Dataset.csv")
# Out:
# C:\Users\HP 850G2\AppData\Local\Temp\ipykernel_2216\4270612918.py:1: DtypeWarning: Columns (0: increment_id) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Pakistan Largest Ecommerce Dataset.csv")

# %%
df.head()
# Out:
#    item_id          status created_at  \
# 0   211131        complete   7/1/2016
# 1   211133        canceled   7/1/2016
# 2   211134        canceled   7/1/2016
# 3   211135        complete   7/1/2016
# 4   211136  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0            1
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0            1
# 2                                 Ego_UP0017-999-MR0  2450.0            1
# 3                                     kcc_krone deal   360.0            1
# 4                                        BK7010400AG   555.0            2
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 584524 entries, 0 to 584523
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  int64
#  1   status                 584509 non-null  str
#  2   created_at             584524 non-null  str
#  3   sku                    584504 non-null  str
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  int64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  str
#  9   sales_commission_code  447346 non-null  str
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  str
#  12  Working Date           584524 non-null  str
#  13  BI Status              584524 non-null  str
#  14  MV                     584524 non-null  str
# ...

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                       15
# created_at                    0
# sku                          20
# price                         0
# qty_ordered                   0
# grand_total                   0
# increment_id                  0
# category_name_1             164
# sales_commission_code    137178
# discount_amount               0
# payment_method                0
# Working Date                  0
# BI Status                     0
# MV                            0
# Year                          0
# Month                         0
# Customer Since               11
# M-Y                           0
# FY                            0
# Customer ID                  11
# dtype: int64

# %%
df = df.drop(columns=['sales_commission_code'])

# %%
df.shape
# Out:
# (584524, 20)

# %%
df.head()
# Out:
#    item_id          status created_at  \
# 0   211131        complete   7/1/2016
# 1   211133        canceled   7/1/2016
# 2   211134        canceled   7/1/2016
# 3   211135        complete   7/1/2016
# 4   211136  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0            1
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0            1
# 2                                 Ego_UP0017-999-MR0  2450.0            1
# 3                                     kcc_krone deal   360.0            1
# 4                                        BK7010400AG   555.0            2
#
#    grand_total increment_id    category_name_1  discount_amount  \
# 0       1950.0    100147443    Women's Fashion              0.0
# 1        240.0    100147444  Beauty & Grooming              0.0
# 2       2450.0    100147445    Women's Fashion              0.0
# ...

# %%
df.sku
# Out:
# 0                                         kreations_YI 06-L
# 1         kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...
# 2                                        Ego_UP0017-999-MR0
# 3                                            kcc_krone deal
# 4                                               BK7010400AG
#                                 ...
# 584519                                  WOFSCE5AE00357AECDE
# 584520                                  MATHUA5AF70A7D1E50A
# 584521                                  MATSAM5B6D7208C6D30
# 584522                                  MATSAM5B1509B4696EA
# 584523                                  MATSAM5B10F91A9B6AB
# Name: sku, Length: 584524, dtype: str

# %%
df["MV"]
# Out:
# 0           1,950
# 1             240
# 2           2,450
# 3             360
# 4           1,110
#            ...
# 584519        699
# 584520     35,599
# 584521    259,998
# 584522    174,600
# 584523    217,280
# Name: MV, Length: 584524, dtype: str

# %%
df["item_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dropna(subset=['Customer ID', 'sku', 'status', 'category_name_1', 'Customer Since'], inplace=True)

# %%
df
# Out:
#         item_id          status created_at  \
# 0        211131        complete   7/1/2016
# 1        211133        canceled   7/1/2016
# 2        211134        canceled   7/1/2016
# 3        211135        complete   7/1/2016
# 4        211136  order_refunded   7/1/2016
# ...         ...             ...        ...
# 584519   905204             cod  8/28/2018
# 584520   905205      processing  8/28/2018
# 584521   905206      processing  8/28/2018
# 584522   905207      processing  8/28/2018
# 584523   905208      processing  8/28/2018
#
#                                                       sku     price  \
# 0                                       kreations_YI 06-L    1950.0
# 1       kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...     240.0
# 2                                      Ego_UP0017-999-MR0    2450.0
# 3                                          kcc_krone deal     360.0
# 4                                             BK7010400AG     555.0
# ...

# %%
df.shape
# Out:
# (584314, 20)

# %%
df.isnull().sum()
# Out:
# item_id            0
# status             0
# created_at         0
# sku                0
# price              0
# qty_ordered        0
# grand_total        0
# increment_id       0
# category_name_1    0
# discount_amount    0
# payment_method     0
# Working Date       0
# BI Status          0
# MV                 0
# Year               0
# Month              0
# Customer Since     0
# M-Y                0
# FY                 0
# Customer ID        0
# dtype: int64

# %%
# remove grand_total, discout amount -ve values

df = df[df['discount_amount'] >= 0]

# %%
df = df[df['grand_total'] >= 0]

# %%
df.shape
# Out:
# (584235, 20)

# %%
df.status.value_counts()
# Out:
# status
# complete          233657
# canceled          201107
# received           77274
# order_refunded     59494
# refund              8002
# cod                 2854
# paid                1159
# closed               494
# payment_review        57
# pending               48
# processing            33
# holded                31
# fraud                 10
# pending_paypal         7
# exchange               4
# \N                     4
# Name: count, dtype: int64

# %%
df.category_name_1.value_counts()
# Out:
# category_name_1
# Mobiles & Tablets     115700
# Men's Fashion          92214
# Women's Fashion        59716
# Appliances             52404
# Superstore             43596
# Beauty & Grooming      41488
# Soghaat                34002
# Others                 29208
# Home & Living          26502
# Entertainment          26317
# Health & Sports        17498
# Kids & Baby            16488
# Computing              15930
# \N                      7832
# School & Education      3470
# Books                   1870
# Name: count, dtype: int64

# %%
df.payment_method.value_counts()
# Out:
# payment_method
# cod                  271770
# Payaxis               97616
# Easypay               82854
# jazzwallet            35145
# easypay_voucher       31175
# bankalfalah           23041
# jazzvoucher           15633
# Easypay_MA            14026
# customercredit         7554
# apg                    1758
# ublcreditcard           882
# cashatdoorstep          732
# mcblite                 723
# mygateway               669
# internetbanking         472
# productcredit           125
# marketingexpense         45
# financesettlement        15
# Name: count, dtype: int64

# %%
df['BI Status'].value_counts()
# Out:
# BI Status
# Net      234150
# Gross    201297
# Valid    148787
# #REF!         1
# Name: count, dtype: int64

# %%
df.grand_total.value_counts()
# Out:
# grand_total
# 0.0        9616
# 1000.0     5145
# 2000.0     3780
# 2500.0     3235
# 5000.0     2912
#            ...
# 7816.0        1
# 2311.0        1
# 27280.0       1
# 28599.0       1
# 23510.0       1
# Name: count, Length: 36800, dtype: int64

# %%
df.isnull().sum()
# Out:
# item_id            0
# status             0
# created_at         0
# sku                0
# price              0
# qty_ordered        0
# grand_total        0
# increment_id       0
# category_name_1    0
# discount_amount    0
# payment_method     0
# Working Date       0
# BI Status          0
# MV                 0
# Year               0
# Month              0
# Customer Since     0
# M-Y                0
# FY                 0
# Customer ID        0
# dtype: int64

# %%
col_list = df.columns
col_list
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1', 'discount_amount',
#        'payment_method', 'Working Date', 'BI Status', 'MV', 'Year', 'Month',
#        'Customer Since', 'M-Y', 'FY', 'Customer ID'],
#       dtype='str')

# %%
for i in col_list:
    print(f"{i}:",len(df[df[f"{i}"] == '\\N']))
# Out:
# item_id: 0
# status: 4
# created_at: 0
# sku: 0
# price: 0
# qty_ordered: 0
# grand_total: 0
# increment_id: 0
# category_name_1: 7832
# discount_amount: 0
# payment_method: 0
# Working Date: 0
# BI Status: 0
# MV: 0
# Year: 0
# Month: 0
# Customer Since: 0
# M-Y: 0
# FY: 0
# Customer ID: 0

# %%
df = df[df['status'] != '\\N']

# %%
df.shape
# Out:
# (584231, 20)

# %%
df['category_name_1'] = df['category_name_1'].replace('\\N', 'Unknown')

# %%
for i in col_list:
    print(f"{i}:",len(df[df[f"{i}"] == '\\N']))
# Out:
# item_id: 0
# status: 0
# created_at: 0
# sku: 0
# price: 0
# qty_ordered: 0
# grand_total: 0
# increment_id: 0
# category_name_1: 0
# discount_amount: 0
# payment_method: 0
# Working Date: 0
# BI Status: 0
# MV: 0
# Year: 0
# Month: 0
# Customer Since: 0
# M-Y: 0
# FY: 0
# Customer ID: 0

# %%
df.shape
# Out:
# (584231, 20)

# %%
df['status'] = df['status'].replace(['complete', 'received', 'paid', 'cod', 'closed'], 'completed')

# %%
df['status'] = df['status'].replace(['refund', 'order_refunded'], 'refunded')

# %%
df['status'] = df['status'].replace(['pending','processing','payment_review','pending_paypal', 'holded'], 'pending')

# %%
df.status.value_counts()
# Out:
# status
# completed    315438
# canceled     201107
# refunded      67496
# pending         176
# fraud            10
# exchange          4
# Name: count, dtype: int64

# %%
df
# Out:
#         item_id     status created_at  \
# 0        211131  completed   7/1/2016
# 1        211133   canceled   7/1/2016
# 2        211134   canceled   7/1/2016
# 3        211135  completed   7/1/2016
# 4        211136   refunded   7/1/2016
# ...         ...        ...        ...
# 584519   905204  completed  8/28/2018
# 584520   905205    pending  8/28/2018
# 584521   905206    pending  8/28/2018
# 584522   905207    pending  8/28/2018
# 584523   905208    pending  8/28/2018
#
#                                                       sku     price  \
# 0                                       kreations_YI 06-L    1950.0
# 1       kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...     240.0
# 2                                      Ego_UP0017-999-MR0    2450.0
# 3                                          kcc_krone deal     360.0
# 4                                             BK7010400AG     555.0
# ...                                                   ...       ...
# ...

# %%
df.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1', 'discount_amount',
#        'payment_method', 'Working Date', 'BI Status', 'MV', 'Year', 'Month',
#        'Customer Since', 'M-Y', 'FY', 'Customer ID'],
#       dtype='str')

# %%
df.to_csv('../data/pakistan_larget_ecommerce_clean_dataset.csv', index=False)

# %%
df['grand_total'].sum()
# Out:
# np.float64(4985899510.0965)

# %%
df['category_name_1'].value_counts()
# Out:
# category_name_1
# Mobiles & Tablets     115700
# Men's Fashion          92214
# Women's Fashion        59716
# Appliances             52404
# Superstore             43596
# Beauty & Grooming      41488
# Soghaat                34002
# Others                 29208
# Home & Living          26502
# Entertainment          26317
# Health & Sports        17498
# Kids & Baby            16488
# Computing              15930
# Unknown                 7828
# School & Education      3470
# Books                   1870
# Name: count, dtype: int64

# %%
df[df['category_name_1'] == 'Unknown']
# Out:
#         item_id     status  created_at                    sku   price  \
# 24       211157   refunded    7/1/2016  D Lend a Helping Hand  1000.0
# 72       211214   canceled    7/1/2016     sentiments_WRK1612     1.0
# 79       211222   canceled    7/1/2016     sentiments_WRK1612     1.0
# 80       211223   canceled    7/1/2016     sentiments_WRK1612     1.0
# 81       211225   canceled    7/1/2016     sentiments_WRK1612     1.0
# ...         ...        ...         ...                    ...     ...
# 423207   722206   refunded  12/27/2017    OTHOTH5A0945D0A72F4    90.0
# 423231   722242  completed  12/27/2017  MEFQMO59B0942707B79-L    99.0
# 423826   722915   refunded  12/29/2017    OTHOTH5A0945D0A72F4    90.0
# 423829   722918   refunded  12/29/2017  MEFQMO59B0942707B79-S    99.0
# 423830   722920  completed  12/29/2017  MEFQMO59B0942707B79-L    99.0
#
#         qty_ordered  grand_total increment_id category_name_1  \
# 24                1          0.0    100147461         Unknown
# ...

# %%
df
# Out:
#         item_id     status created_at  \
# 0        211131  completed   7/1/2016
# 1        211133   canceled   7/1/2016
# 2        211134   canceled   7/1/2016
# 3        211135  completed   7/1/2016
# 4        211136   refunded   7/1/2016
# ...         ...        ...        ...
# 584519   905204  completed  8/28/2018
# 584520   905205    pending  8/28/2018
# 584521   905206    pending  8/28/2018
# 584522   905207    pending  8/28/2018
# 584523   905208    pending  8/28/2018
#
#                                                       sku     price  \
# 0                                       kreations_YI 06-L    1950.0
# 1       kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...     240.0
# 2                                      Ego_UP0017-999-MR0    2450.0
# 3                                          kcc_krone deal     360.0
# 4                                             BK7010400AG     555.0
# ...                                                   ...       ...
# ...

# %%
df['payment_method'].value_counts()
# Out:
# payment_method
# cod                  271766
# Payaxis               97616
# Easypay               82854
# jazzwallet            35145
# easypay_voucher       31175
# bankalfalah           23041
# jazzvoucher           15633
# Easypay_MA            14026
# customercredit         7554
# apg                    1758
# ublcreditcard           882
# cashatdoorstep          732
# mcblite                 723
# mygateway               669
# internetbanking         472
# productcredit           125
# marketingexpense         45
# financesettlement        15
# Name: count, dtype: int64

# %%
df['BI Status'].value_counts()
# Out:
# BI Status
# Net      234150
# Gross    201293
# Valid    148787
# #REF!         1
# Name: count, dtype: int64

# %%
df = pd.read_csv("../data/pakistan_larget_ecommerce_clean_dataset.csv")

df['sku']
# Out:
# C:\Users\HP 850G2\AppData\Local\Temp\ipykernel_6272\49245749.py:1: DtypeWarning: Columns (0: increment_id) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/pakistan_larget_ecommerce_clean_dataset.csv")
# 0                                         kreations_YI 06-L
# 1         kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...
# 2                                        Ego_UP0017-999-MR0
# 3                                            kcc_krone deal
# 4                                               BK7010400AG
#                                 ...
# 584226                                  WOFSCE5AE00357AECDE
# 584227                                  MATHUA5AF70A7D1E50A
# 584228                                  MATSAM5B6D7208C6D30
# 584229                                  MATSAM5B1509B4696EA
# 584230                                  MATSAM5B10F91A9B6AB
# Name: sku, Length: 584231, dtype: str

# %%
mv = df[df['price'] <= 0]

# %%
mv['MV']
# Out:
# 6598       -
# 6603       -
# 7004       -
# 8298       -
# 8333       -
#           ...
# 583967     -
# 583968     -
# 583971     -
# 583977     -
# 583978     -
# Name: MV, Length: 2214, dtype: str

# %%
mv
# Out:
#         item_id     status created_at  \
# 6598     218538   canceled  7/26/2016
# 6603     218542   canceled  7/26/2016
# 7004     218988   canceled  7/27/2016
# 8298     220494   canceled  7/29/2016
# 8333     220540   canceled  7/29/2016
# ...         ...        ...        ...
# 583967   904901  completed  8/27/2018
# 583968   904902  completed  8/27/2018
# 583971   904906  completed  8/27/2018
# 583977   904916  completed  8/27/2018
# 583978   904917  completed  8/27/2018
#
#                                                       sku  price  qty_ordered  \
# 6598    west point_Deluxe Juicer, Blender & Grinder - ...    0.0            1
# 6603    west point_Deluxe Juicer, Blender & Grinder - ...    0.0            1
# 7004    west point_Deluxe Juicer, Blender & Grinder - ...    0.0            1
# 8298                                         stinnos_1301    0.0            1
# 8333                                         stinnos_1301    0.0           10
# ...

# %%
mv['status'].value_counts()
# Out:
# status
# completed    841
# canceled     741
# refunded     632
# Name: count, dtype: int64

# %%
mv['sku'].value_counts()
# Out:
# sku
# BKSTRA59F192793463E       348
# Bahr-e-Shifa              205
# BKSTRA59BA5A46D211B       125
# Infinix Hot 4-Gold-1       63
# BAGPRI5A327299C4F97        51
#                          ...
# MEFAYB5ACB543D2B29C-L       1
# MEFAYB5ACB543D2B29C-XL      1
# HASTEC5AF986D02EC8E-XL      1
# ENTSON5A449A78B1823         1
# APPVIT5A9D2C337C7A5         1
# Name: count, Length: 465, dtype: int64

# %%
mv[(mv['status'] == 'completed') & (mv['grand_total'] > 0)]
# Out:
#         item_id     status created_at                        sku  price  \
# 8358     220568  completed  7/29/2016               stinnos_1301    0.0
# 8771     221032  completed  7/31/2016               stinnos_1301    0.0
# 11054    224392  completed   8/5/2016  cr_PEANUT CHIKKIE SPECIAL    0.0
# 12165    226019  completed   8/8/2016  cr_PEANUT CHIKKIE SPECIAL    0.0
# 12360    226329  completed   8/8/2016  cr_PEANUT CHIKKIE SPECIAL    0.0
# ...         ...        ...        ...                        ...    ...
# 583967   904901  completed  8/27/2018        COMTOO59D5164EE7D18    0.0
# 583968   904902  completed  8/27/2018        COMTOO59D5164EE7D18    0.0
# 583971   904906  completed  8/27/2018        COMTOO59D5164EE7D18    0.0
# 583977   904916  completed  8/27/2018        COMTOO59D5164EE7D18    0.0
# 583978   904917  completed  8/27/2018        COMTOO59D5164EE7D18    0.0
#
#         qty_ordered  grand_total increment_id category_name_1  \
# ...

# %%
df['status'].value_counts()
# Out:
# status
# completed    315438
# canceled     201107
# refunded      67496
# pending         176
# fraud            10
# exchange          4
# Name: count, dtype: int64

# %%
df[(df['price'] > 0) & (df['grand_total'] == 0)]
# Out:
#         item_id     status created_at                        sku    price  \
# 14       211146  completed   7/1/2016           kcc_glamour deal    320.0
# 24       211157   refunded   7/1/2016      D Lend a Helping Hand   1000.0
# 27       211162  completed   7/1/2016            SKMT_Blood Test    500.0
# 28       211163  completed   7/1/2016              SKMT_Medicine    100.0
# 266      211422  completed   7/1/2016  sstop_3dcreenwithspeakers    995.0
# ...         ...        ...        ...                        ...      ...
# 583970   904904  completed  8/27/2018      MEFRED5B445E6B94853-S    837.0
# 584075   905028  completed  8/27/2018        ENTECO5A7FE80D6C830  20599.0
# 584112   905080  completed  8/27/2018      MEFC-T5A79B6E8346D9-M    799.0
# 584221   905196  completed  8/28/2018     MEFGUL5A9F882AA5B99-36   1299.0
# 584222   905198  completed  8/28/2018        MEFPAK5B360B03C6B72    999.0
#
#         qty_ordered  grand_total increment_id    category_name_1  \
# ...

# %%
ch = df[(df['price'] > 0) & (df['grand_total'] == 0)]

# %%
ch['BI Status'].value_counts()
# Out:
# BI Status
# Net      5112
# Valid    4069
# Gross     284
# Name: count, dtype: int64

# %%
ch['status'].value_counts()
# Out:
# status
# completed    7406
# refunded     1775
# canceled      284
# Name: count, dtype: int64

# %%
ch[ch['MV'] == ch['price']]
# Out:
# Empty DataFrame
# Columns: [item_id, status, created_at, sku, price, qty_ordered, grand_total, increment_id, category_name_1, discount_amount, payment_method, Working Date, BI Status, MV, Year, Month, Customer Since, M-Y, FY, Customer ID]
# Index: []

# %%
gt = df['grand_total'].sum()
mvt = df['MV'].sum()
pt = df['price'].sum()

# %%
gt
# Out:
# np.float64(4985899510.0965)

# %%
mvt
# Out:
# '1,9502402,4503601,1108036017096,49996,4995,5002101561203201,5504203604908998993201491491,0001,9131,9135005003,00045020,999360165435908503,672908508997,4003,6001432254,5003,1562,99660030093038035042585025136051032530030,41736070045,25024,3002885,5979994,95080536028019993603503507604355213603204357602403601,8757604353603604357603204,2007604355501,23043576076043532032051037023201,4403603202403501,9507954,7507,400320240520520320360360320240320510370360260260803201260260803603603,90013603601,45013603603,950360260260803603603603607603602602608042530019021036026026080350350260260807603603602807602602608036076036036036036032036024035016,460599599360360265903603601203603602609036025036025,9993202403603603,9003603,600360360450360700150143753604503603603601403504505503501,0503,75024554252,67010,7402302302803003007994801,2004,5301,890803702151,3502,4901,6501,8702,0509953602,1603501701702853201,0992407206403,2904803603203603201,6905002,8002,5505709031503603203603603603603603607003607003203503203
# ...

# %%
pt
# Out:
# np.float64(3710606594.1299996)

# %%
df['Customer ID'].unique().sum()
# Out:
# np.float64(nan)

# %%
df['Customer ID'].drop_duplicates().sum()
# Out:
# np.float64(6650100801.0)

# %%
df['Customer ID'].sum()
# Out:
# np.float64(26765149520.0)

# %%
df['item_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#         item_id          status created_at  \
# 0        211131        complete   7/1/2016
# 1        211133        canceled   7/1/2016
# 2        211134        canceled   7/1/2016
# 3        211135        complete   7/1/2016
# 4        211136  order_refunded   7/1/2016
# ...         ...             ...        ...
# 584519   905204             cod  8/28/2018
# 584520   905205      processing  8/28/2018
# 584521   905206      processing  8/28/2018
# 584522   905207      processing  8/28/2018
# 584523   905208      processing  8/28/2018
#
#                                                       sku     price  \
# 0                                       kreations_YI 06-L    1950.0
# 1       kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...     240.0
# 2                                      Ego_UP0017-999-MR0    2450.0
# 3                                          kcc_krone deal     360.0
# 4                                             BK7010400AG     555.0
# ...

# %%
df['grand_total'].mean()
# Out:
# np.float64(8530.618570950894)
